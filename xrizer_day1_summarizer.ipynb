# %% [markdown]
# <a href="https://colab.research.google.com/github/Piyushwrites/xrizer/blob/main/xrizer_day1_summarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ========================
# PROJECT XRIZER - DAY 1 FIXED (2026 Version)
# ========================

# !pip install --upgrade -q google-generativeai

import google.generativeai as genai

# === PASTE YOUR FULL GEMINI KEY HERE ===
genai.configure(api_key="AIzaSyCan1KIZL3Eveeam2lZkjj-EhYCvfjkO8o")

print("✅ Library updated to latest version")
print("✅ Gemini connected successfully!")
# Out:
# ✅ Library updated to latest version
# ✅ Gemini connected successfully!

# %%
# This shows every model available to you right now
print("🔍 Available models for your Gemini key:")
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# 🔍 Available models for your Gemini key:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# ...

# %%
# Use the best current fast model in 2026
model = genai.GenerativeModel("gemini-2.5-flash")

print("🚀 Xrizer brain loaded with gemini-2.5-flash!")
# Out:
# 🚀 Xrizer brain loaded with gemini-2.5-flash!

# %%
# ========================
# CELL 4: YOUR FIRST XRIZER SUMMARY (THE MAGIC MOMENT)
# ========================

# === TEST YOUR FIRST SUMMARY ===
text = """Team meeting today: We discussed Q1 sales targets. Sales are 15% below target. Marketing team needs to run 2 new campaigns by 5th March. Piyush will prepare the budget report by tomorrow evening. Everyone agreed to weekly check-ins on Zoom."""

prompt = f"""You are Xrizer - the world's best AI meeting & video summarizer.

Summarize the text below in this exact format:

**📋 Summary**
- Bullet 1
- Bullet 2
- Bullet 3

**✅ Action Items**
• Who → What → By when

Text:
{text}
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# **📋 Summary**
# - Discussed Q1 sales targets.
# - Sales are currently 15% below target.
# - Agreed to hold weekly check-ins on Zoom.
#
# **✅ Action Items**
# • Marketing team → Run 2 new campaigns → By 5th March
# • Piyush → Prepare the budget report → By tomorrow evening
